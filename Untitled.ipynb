# %%
import pandas as pd

# %%
df = pd.read_excel("dlt_expert_2025027.xlsx")

# %%
df = pd.read_csv("dlt_pageno_users_2025027.csv")
df["userids"] = df["userids"].map(eval)

# %%
1500 / 7
# Out:
# 214.28571428571428

# %%
214.3*7
# Out:
# 1500.1000000000001
